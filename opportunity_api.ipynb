# %% [markdown]
# # Opportunity StatWolf API

# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv()

api_id = os.getenv("API_ID")
api_pwd = os.getenv("API_PWD")

host = "https://opportunitystatwolf.opportunitycrm.it/API"

response = requests.post(
    f"{host}/auth/token",
    json={
        "apiId": api_id,
        "apiPassword": api_pwd
    }
)

if response.status_code == 200:
    print("Authentication successful. Token received.")
    data = response.json()
    token = data.get("token")
    refresh_token = data.get("refreshToken")
# Out:
# Authentication successful. Token received.

# %%
# Bearer token
headers = {
    "authorization": f"Bearer {token}"
}

# %%
params = {
    "PIVA": 1724220700
}
response = requests.get(
    f"{host}/clienti",
    headers=headers,
    params=params
)

if response.status_code == 200:
    print("Clienti retrieved successfully.")
    clienti = response.json()
    for cliente in clienti:
        print(cliente)
# Out:
# Clienti retrieved successfully.
# {'id': 1, 'codice': '16206', 'ragioneSociale': 'CLIENTE VINCHIATURO 16206', 'indirizzo': 'CONTRADA LE MACERE SNC', 'cap': '86019', 'comune': 'VINCHIATURO', 'provincia': 'CB', 'nazione': 'Italia', 'piva': '01724220700', 'cf': '', 'telefono1': '0874.69106', 'telefono2': '', 'cellulare1': '', 'cellulare2': '', 'email': 'anonimo@16206.it', 'www': ''}

# %% [markdown]
# ## Attività

# %% [markdown]
# */attivita/tipi* ritorna i tipi di attività.
#
# * Nessun parametro
#
# ```json
#     [
#         {
#         "id": 0,
#         "codice": "string",
#         "descrizione": "string",
#         "todo": true,
#         "modulo": "string",
#         "steplevel": 0,
#         "codiceParent": "string",
#         "defaultChiuso": true,
#         "dataFutura": true,
#         "visita": true,
#         "durata": 0,
#         "idCalendario": 0,
#         "istruzioniAI": "string"
#         }
#     ]
# ```

# %%
response = requests.get(
    f"{host}/attivita/tipi",
    headers=headers
)

if response.status_code == 200:
    print("Activity types retrieved successfully.")
    activity_types = response.json()
    for activity_type in activity_types:
        id = activity_type.get("id")
        code = activity_type.get("codice")
        description = activity_type.get("descrizione")
        todo = activity_type.get("todo")
        module = activity_type.get("modulo")
        step_level = activity_type.get("steplevel")
        code_parent = activity_type.get("codiceParent")
        default_chiuso = activity_type.get("defaultChiuso")
        bill_date = activity_type.get("dataFattura")
        visita = activity_type.get("visita")
        durata = activity_type.get("durata")
        id_calendario = activity_type.get("idCalendario")
        istruzioni_ai = activity_type.get("istruzioniAI")
        print(f"ID: {id}, Code: {code}, Description: {description}, Todo: {todo}, Module: {module}, Step Level: {step_level}, Parent Code: {code_parent}, Default Closed: {default_chiuso}, Bill Date: {bill_date}, Visit: {visita}, Duration: {durata}, Calendar ID: {id_calendario}, AI Instructions: {istruzioni_ai}")
        print("-" * 40)
# Out:
# Activity types retrieved successfully.
# ID: 2, Code: CH_TODO, Description: Chiusura ToDo, Todo: False, Module: cl, Step Level: 1, Parent Code: ToDo, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 5, Code: todo, Description: Generico ToDo, Todo: True, Module: cl, Step Level: 0, Parent Code: 0, Default Closed: False, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 6, Code: incontro_cliente, Description: Esito Incontro, Todo: False, Module: cl, Step Level: 0, Parent Code: FIS_INC, Default Closed: True, Bill Date: None, Visit: True, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 7, Code: FIS_INC, Description: Pianifica Incontro, Todo: True, Module: cl, Step Level: 0, Parent Code: None, Default Closed: False, Bill Date: None, Visit: True, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 12, Code: OFF_OK, Description: Off. Da Spedire, Todo: True, Module: of, Step Level: 1, Parent Code: 0, Default Closed: False, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 13, Code: CH_OFF_OK, Description: Off. Spedita, Todo: False, Module: of, Step Level: 1, Parent Code: OFF_OK, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 14, Code: CH_LAM_3, Description: Chiusura Lamentela (terzi), Todo: False, Module: cl, Step Level: 1, Parent Code: LAM_3, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 15, Code: CH_IN_DOC_3, Description: Documentazione inviata al Cliente (terzi), Todo: False, Module: cl, Step Level: 1, Parent Code: IN_DOC_3, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 16, Code: CH_RIC_CLI, Description: Telefonata Cliente Effettuata, Todo: False, Module: cl, Step Level: 0, Parent Code: RIC_CLI, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 17, Code: CH_TD_GEN_3, Description: Chiusura ToDo Generico (terzi), Todo: False, Module: cl, Step Level: 1, Parent Code: TD_GEN_3, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 18, Code: CH_TEL_OFF, Description: Telefonata Scad. Off, Todo: False, Module: cl, Step Level: 1, Parent Code: TEL_OFF, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 19, Code: CH_CR_OFF, Description: Offerta Creata, Todo: False, Module: cl, Step Level: 1, Parent Code: CR_OFF, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 20, Code: CH_CR_OFF_3, Description: Offerta Creata (terzi), Todo: False, Module: cl, Step Level: 1, Parent Code: CR_OFF_3, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 21, Code: CH_CR_ORD, Description: Ordine Creato, Todo: False, Module: cl, Step Level: 1, Parent Code: CR_ORD, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 22, Code: CH_CR_ORD_3, Description: Ordine Creato (terzi), Todo: False, Module: cl, Step Level: 1, Parent Code: CR_ORD_3, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 31, Code: RIC_CLI, Description: Richiamare Cliente, Todo: True, Module: cl, Step Level: 1, Parent Code: None, Default Closed: False, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 34, Code: CH_OFF_KO, Description: Offerta Persa, Todo: False, Module: of, Step Level: 1, Parent Code: OFF_OK, Default Closed: False, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 35, Code: CH_OFF_VINTA, Description: Offerta Vinta, Todo: False, Module: of, Step Level: 1, Parent Code: OFF_OK, Default Closed: False, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 39, Code: CH_IND_DOC, Description: Documentazione inviata al Cliente, Todo: False, Module: cl, Step Level: 1, Parent Code: IN_DOC, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 40, Code: CH_REP_INT, Description: Report Interno, Todo: False, Module: cl, Step Level: 0, Parent Code: None, Default Closed: True, Bill Date: None, Visit: False, Duration: 5, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 41, Code: CH_FP_3, Description: Chiusura Fuori Prezzo (terzi), Todo: False, Module: cl, Step Level: 1, Parent Code: FP_3, Default Closed: True, Bill Date: None, Visit: False, Duration: 5, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 42, Code: CH_TR_NP_RF, Description: Richiesta Fornitore, Todo: False, Module: tr, Step Level: 1, Parent Code: TR_NP_RF, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 43, Code: CH_TR_NP_RSF, Description: Riposta fornitore, Todo: False, Module: tr, Step Level: 1, Parent Code: TR_NP_RSF, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 44, Code: CH_TR_NP_CC, Description: Comunicazione Cliente, Todo: False, Module: tr, Step Level: 1, Parent Code: TR_NP_CC, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 45, Code: CH_VER_TR, Description: Campionatura verificata, Todo: False, Module: tr, Step Level: 1, Parent Code: VER_TR, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 46, Code: CH_PR_CAMP, Description: Campionatura preparata, Todo: False, Module: tr, Step Level: 1, Parent Code: PR_CAMP, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 47, Code: CH_QARF, Description: Risposta fornitore, Todo: False, Module: qa, Step Level: 1, Parent Code: QARF, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 48, Code: CH_QACL, Description: Lotto controllato, Todo: False, Module: qa, Step Level: 1, Parent Code: QACL, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 49, Code: CH_QAICL, Description: Azioni correttive, Todo: False, Module: qa, Step Level: 1, Parent Code: QAICL, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 50, Code: FP_RICH, Description: Richiesta Ferie/Perm Altro, Todo: True, Module: us, Step Level: 0, Parent Code: 0, Default Closed: False, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 51, Code: FP_RICH_OK, Description: FP Approvate, Todo: False, Module: us, Step Level: 1, Parent Code: FP_RICH, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 52, Code: FP_RICH_KO, Description: FP Non App., Todo: False, Module: us, Step Level: 1, Parent Code: FP_RICH, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 53, Code: TODOALL, Description: Da fare, Todo: True, Module: ALL, Step Level: 0, Parent Code: 0, Default Closed: False, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 54, Code: CH_TODOALL, Description: Eseguito, Todo: False, Module: ALL, Step Level: 1, Parent Code: TODOALL, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 55, Code: INC_FO, Description: Esito Inc. Forn., Todo: False, Module: fo, Step Level: 0, Parent Code: None, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 56, Code: CH_REP_INT_FO, Description: Report Int. Forn., Todo: False, Module: fo, Step Level: 0, Parent Code: None, Default Closed: True, Bill Date: None, Visit: False, Duration: 5, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 57, Code: CH_TEL_FO, Description: Tel Forn. Effettuata, Todo: False, Module: fo, Step Level: 0, Parent Code: None, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 58, Code: TODOVALL, Description: Incontro, Todo: True, Module: ALL, Step Level: 0, Parent Code: None, Default Closed: False, Bill Date: None, Visit: True, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 59, Code: CH_TODOVALL, Description: Incontro Effettuato, Todo: False, Module: ALL, Step Level: 1, Parent Code: TODOVALL, Default Closed: True, Bill Date: None, Visit: True, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 60, Code: GENORD, Description: Creare Ordine, Todo: True, Module: cl, Step Level: 1, Parent Code: None, Default Closed: False, Bill Date: None, Visit: False, Duration: None, Calendar ID: 46, AI Instructions: None
# ----------------------------------------
# ID: 61, Code: CH_GENORD, Description: Ordine Creato, Todo: False, Module: cl, Step Level: 1, Parent Code: GENORD, Default Closed: True, Bill Date: None, Visit: False, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------
# ID: 67, Code: CH_INC_ARB, Description: Esito Visita ARBUG Cliente, Todo: False, Module: cl, Step Level: 0, Parent Code: INC_ARB, Default Closed: True, Bill Date: None, Visit: True, Duration: None, Calendar ID: None, AI Instructions: None
# ----------------------------------------

# %% [markdown]
# */attivita/stati* ritorna gli stati delle attività:
# 1. AP <- aperto
# 2. IC <- in corso
# 3. CH <- chiuso
#
# * Nessun parametro
#
# ```json
#     [
#         {
#             "id": 0,
#             "codice": "string",
#             "descrizione": "string"
#         }
#     ]
# ```

# %%
response = requests.get(
    f"{host}/attivita/stati",
    headers=headers
)

if response.status_code == 200:
    print("Activity states retrieved successfully.")
    activity_states = response.json()
    for activity_state in activity_states:
        id = activity_state.get("id")
        code = activity_state.get("codice")
        description = activity_state.get("descrizione")
        print(f"ID: {id}, Code: {code}, Description: {description}")
        print("-" * 40)
# Out:
# Activity states retrieved successfully.
# ID: 1, Code: AP, Description: APERTO
# ----------------------------------------
# ID: 2, Code: IC, Description: IN CORSO
# ----------------------------------------
# ID: 3, Code: CH, Description: CHIUSO
# ----------------------------------------

# %% [markdown]
# * */attivita/attivita/{id}*: Ritorna la specifica attività
# * Parametri:
#   * **id**: id dell'attività (**richiesto**)
#
# ```json
# {
#   "id": 0,
#   "dataRegistrazione": "2025-07-07T13:49:26.042Z",
#   "dataInizio": "2025-07-07T13:49:26.042Z",
#   "dataFine": "2025-07-07T13:49:26.042Z",
#   "idCalendario": 0,
#   "idStato": 0,
#   "idUtente": 0,
#   "idCliente": 0,
#   "idTipoAtt": 0,
#   "idDestinazione": 0,
#   "idContatto": 0,
#   "isTodo": true,
#   "dataEsecuzione": "2025-07-07T13:49:26.042Z",
#   "oggetto": "string",
#   "testo": "string",
#   "note": "string",
#   "giornataIntera": true,
#   "idAttParent": 0,
#   "codiceTodoType": "string"
# }
# ```

# %%
id_activity = 2

response = requests.get(
    f"{host}/attivita/attivita/{id_activity}",
    headers=headers
)

if response.status_code == 200:
    print(f"Activity {id_activity} retrieved successfully.")
    activity = response.json()
    id = activity.get("id")
    registration_date = activity.get("dataRegistrazione")
    start_date = activity.get("dataInizio")
    end_date = activity.get("dataFine")
    id_calendar = activity.get("idCalendario")
    id_state = activity.get("idStato")
    id_user = activity.get("idUtente")
    id_client = activity.get("idCliente")
    id_type_activity = activity.get("idTipoAtt")
    id_contact = activity.get("idContatto")
    is_todo = activity.get("isTodo")
    exec_date = activity.get("dataEsecuzione")
    object = activity.get("oggetto")
    text = activity.get("testo")
    notes = activity.get("note")
    entire_day = activity.get("giornataIntera")
    id_act_parent = activity.get("idAttParent")
    cod_todo_type = activity.get("codiceTodoType")
    print(f"ID: {id}, Registration Date: {registration_date}, Start Date: {start_date}, End Date: {end_date}, Calendar ID: {id_calendar}, State ID: {id_state}, User ID: {id_user}, Client ID: {id_client}, Activity Type ID: {id_type_activity}, Contact ID: {id_contact}, Is Todo: {is_todo}, Execution Date: {exec_date}, Object: {object}, Text: {text}, Notes: {notes}, Entire Day: {entire_day}, Parent Activity ID: {id_act_parent}, Todo Type Code: {cod_todo_type}")
# Out:
# Activity 2 retrieved successfully.
# ID: 2, Registration Date: 2024-09-18T12:32:11.357, Start Date: 2024-09-18T10:32:11.357, End Date: 2024-09-18T12:32:11.357, Calendar ID: 45, State ID: 3, User ID: 44, Client ID: 1041, Activity Type ID: 6, Contact ID: None, Is Todo: False, Execution Date: 2024-09-18T12:32:11.357, Object: Esito Incontro Cliente, Text: None, Notes: None, Entire Day: None, Parent Activity ID: None, Todo Type Code: None

# %% [markdown]
# Sono presenti altre API che non possono essere utilizzate per l'assenza di clienti:
# * */attivita/attivitaCliente/{id}*: Ritorna tutte le attivita di un cliente
# * Parametri:
#   * **id**: id del cliente di cui recuperare le attività (**richiesto**)
#   * *idStato*: 1 -> aperto, 2 -> in corso, 3 -> chiuso
# ```json
# [
#   {
#     "id": 0,
#     "dataRegistrazione": "2025-07-07T13:47:49.106Z",
#     "dataInizio": "2025-07-07T13:47:49.106Z",
#     "dataFine": "2025-07-07T13:47:49.106Z",
#     "idCalendario": 0,
#     "idStato": 0,
#     "idUtente": 0,
#     "idCliente": 0,
#     "idTipoAtt": 0,
#     "idDestinazione": 0,
#     "idContatto": 0,
#     "isTodo": true,
#     "dataEsecuzione": "2025-07-07T13:47:49.106Z",
#     "oggetto": "string",
#     "testo": "string",
#     "note": "string",
#     "giornataIntera": true,
#     "idAttParent": 0,
#     "codiceTodoType": "string"
#   }
# ]
# ```

# %% [markdown]
# ## Clienti

# %% [markdown]
# */clienti* dovrebbe ritornare una lista di clienti, con ricerca di diversi parametri come:
# * Ragione Sociale
# * Partita IVA
# * Codice Fiscale
# * Codice (?)
#
# *Non c'è nessun cliente al momento*
#
# * Parametri:
#   * *RagSoc*: Ragione Sociale
#   * *PIVA*: Partita IVA
#   * *CF*: Codice Fiscale
#   * *Codice*: codice (?)
#
# ```json
# [
#   {
#     "id": 0,
#     "codice": "string",
#     "ragioneSociale": "string",
#     "indirizzo": "string",
#     "cap": "string",
#     "comune": "string",
#     "provincia": "string",
#     "nazione": "string",
#     "piva": "string",
#     "cf": "string",
#     "telefono1": "string",
#     "telefono2": "string",
#     "cellulare1": "string",
#     "cellulare2": "string",
#     "email": "string",
#     "www": "string"
#   }
# ]
# ```

# %%
response = requests.get(
    f"{host}/clienti",
    headers=headers
)

if response.status_code == 200:
    print("Clients retrieved successfully.")
    clients = response.json()
    print(clients)
# Out:
# Clients retrieved successfully.
# []

# %% [markdown]
# Sono presenti altre API non utilizzabili dato che non ci sono clienti:
# * */clienti/{id}*: Ritorna un cliente per mezzo del suo id
# * Parametri:
#   * **id**: Id del cliente di cui recuperare i dati (**richiesto**)
#
# ```json
# {
#   "id": 0,
#   "codice": "string",
#   "ragioneSociale": "string",
#   "indirizzo": "string",
#   "cap": "string",
#   "comune": "string",
#   "provincia": "string",
#   "nazione": "string",
#   "piva": "string",
#   "cf": "string",
#   "telefono1": "string",
#   "telefono2": "string",
#   "cellulare1": "string",
#   "cellulare2": "string",
#   "email": "string",
#   "www": "string"
# }
# ```
#
# * */clienti/destinazioni/{id}*: Ritorna tutte le destinazioni di un cliente
# * Parametri:
#   * **id**: Id del cliente di cui recuperare le destinazioni
#
# ```json
# [
#   {
#     "id": 0,
#     "idCliente": 0,
#     "codice": "string",
#     "descrizione": "string",
#     "indirizzo": "string",
#     "cap": "string",
#     "comune": "string",
#     "provincia": "string",
#     "nazione": "string",
#     "telefono1": "string",
#     "telefono2": "string",
#     "cellulare1": "string",
#     "cellulare2": "string",
#     "email": "string",
#     "note": "string",
#     "sedeLegale": true,
#     "sedeOperativa": true,
#     "destinazioneMerce": true
#   }
# ]
# ```
#
# * */clienti/contatti/{id}*: Ritorna i contatti di un cliente
# * Parametri:
#   * **id**: Id del cliente di cui recuperare i contatti (**richiesto**)
#
# ```json
# [
#   {
#     "id": 0,
#     "idCliente": 0,
#     "codice": "string",
#     "nome": "string",
#     "qualifica": "string",
#     "telefono1": "string",
#     "telefono2": "string",
#     "cellulare1": "string",
#     "cellulare2": "string",
#     "email1": "string",
#     "email2": "string",
#     "cognome": "string",
#     "note": "string",
#     "default": true
#   }
# ]
# ```

# %% [markdown]
# ## Utenti

# %% [markdown]
# */utenti* ritorna una lista degli utenti del CRM
# * Parametri:
#   * *fullname*: ricerca per nome completo
#
# ```json
# [
#   {
#     "id": 0,
#     "fullname": "string",
#     "cognome": "string",
#     "nome": "string",
#     "email": "string",
#     "cellulare": "string",
#     "attivo": true,
#     "dtfval": "2025-07-07T13:57:58.023Z"
#   }
# ]
# ```

# %%
response = requests.get(
    f"{host}/utenti",
    headers=headers
)

if response.status_code == 200:
    print("Users retrieved successfully.")
    users = response.json()
    for user in users:
        id = user.get("id")
        fullname = user.get("fullname")
        cognome = user.get("cognome")
        nome = user.get("nome")
        email = user.get("email")
        cellulare = user.get("cellulare")
        attivo = user.get("attivo")
        dtfval = user.get("dtfval")
        if dtfval:
            date, time = dtfval.split("T") if dtfval else ("", "")
            print(f"ID: {id}, Full Name: {fullname}, Last Name: {cognome}, First Name: {nome}, Email: {email}, Cell: {cellulare}, Active: {attivo}, Valid From: {date} - {time}")
        else:
            print(f"ID: {id}, Full Name: {fullname}, Last Name: {cognome}, First Name: {nome}, Email: {email}, Cell: {cellulare}, Active: {attivo}, Valid From: {dtfval}")
        print("-" * 40)
else:
    print(f"Failed to retrieve users. Status code: {response.status_code}, Error: {response.text}")
# Out:
# Users retrieved successfully.
# ID: 1, Full Name: None, Last Name: None, First Name: None, Email: None, Cell: None, Active: False, Valid From: None
# ----------------------------------------
# ID: 12, Full Name: None, Last Name: None, First Name: None, Email: None, Cell: None, Active: False, Valid From: None
# ----------------------------------------
# ID: 38, Full Name: Ivan Pa, Last Name: Pa, First Name: Ivan, Email: IvanPa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 39, Full Name: Sarah Ka, Last Name: Ka, First Name: Sarah, Email: SarahKa@demo.it, Cell: None, Active: False, Valid From: 2025-02-17 - 00:00:00
# ----------------------------------------
# ID: 40, Full Name: Eliseo Ma, Last Name: Ma, First Name: Eliseo, Email: EliseoMa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 41, Full Name: Luca Po, Last Name: Po, First Name: Luca, Email: LucaPo@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 42, Full Name: Franco Ma, Last Name: Ma, First Name: Franco, Email: FrancoMa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 43, Full Name: Stefano Ba, Last Name: Ba, First Name: Stefano, Email: StefanoBa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 44, Full Name: Linneo Di, Last Name: Di, First Name: Linneo, Email: LinneoDi@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 45, Full Name: Antonio Gu, Last Name: Gu, First Name: Antonio, Email: AntonioGu@demo.it, Cell: None, Active: True, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 46, Full Name: Chiara Gu, Last Name: Gu, First Name: Chiara, Email: ChiaraGu@demo.it, Cell: None, Active: True, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 47, Full Name: Clelio Da, Last Name: Da, First Name: Clelio, Email: ClelioDa@demo.it, Cell: None, Active: True, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 48, Full Name: Filippo Ca, Last Name: Ca, First Name: Filippo, Email: FilippoCa@demo.it, Cell: None, Active: True, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 49, Full Name: Mariateresa Sa, Last Name: Sa, First Name: Mariateresa, Email: MariateresaSa@demo.it, Cell: None, Active: True, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 50, Full Name: Paola Me, Last Name: Me, First Name: Paola, Email: PaolaMe@demo.it, Cell: None, Active: True, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 51, Full Name: Sandra Mo, Last Name: Mo, First Name: Sandra, Email: SandraMo@demo.it, Cell: None, Active: True, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 52, Full Name: Sandro Su, Last Name: Su, First Name: Sandro, Email: SandroSu@demo.it, Cell: None, Active: True, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 53, Full Name: Thomas Ro, Last Name: Ro, First Name: Thomas, Email: ThomasRo@demo.it, Cell: None, Active: True, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 54, Full Name: Adelio Ca, Last Name: Ca, First Name: Adelio, Email: AdelioCa@demo.it, Cell: None, Active: True, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 55, Full Name: Antonio Sa, Last Name: Sa, First Name: Antonio, Email: AntonioSa@demo.it, Cell: None, Active: False, Valid From: 1900-01-01 - 00:00:00
# ----------------------------------------
# ID: 56, Full Name: Tommaso Me, Last Name: Me, First Name: Tommaso, Email: TommasoMe@demo.it, Cell: None, Active: True, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 57, Full Name: None, Last Name: None, First Name: None, Email: None, Cell: None, Active: False, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 58, Full Name: Matteo Va, Last Name: Va, First Name: Matteo, Email: MatteoVa@demo.it, Cell: None, Active: True, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 59, Full Name: Luca Sa, Last Name: Sa, First Name: Luca, Email: LucaSa@demo.it, Cell: None, Active: True, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 60, Full Name: Silvana Ro, Last Name: Ro, First Name: Silvana, Email: SilvanaRo@demo.it, Cell: None, Active: True, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 61, Full Name: Barbara To, Last Name: To, First Name: Barbara, Email: BarbaraTo@demo.it, Cell: None, Active: True, Valid From: 2999-12-31 - 00:00:00
# ----------------------------------------
# ID: 62, Full Name: None, Last Name: None, First Name: None, Email: None, Cell: None, Active: False, Valid From: None
# ----------------------------------------
# ID: 63, Full Name: Alice Mo, Last Name: Mo, First Name: Alice, Email: AliceMo@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 64, Full Name: Anagrazia De, Last Name: De, First Name: Anagrazia, Email: AnagraziaDe@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 65, Full Name: Stefano Sa, Last Name: Sa, First Name: Stefano, Email: StefanoSa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 66, Full Name: Annalisi Mu, Last Name: Mu, First Name: Annalisi, Email: AnnalisiMu@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 67, Full Name: Consuelo Pa, Last Name: Pa, First Name: Consuelo, Email: ConsueloPa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 68, Full Name: Maurizio Co, Last Name: Co, First Name: Maurizio, Email: MaurizioCo@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 69, Full Name: Paola Da, Last Name: Da, First Name: Paola, Email: PaolaDa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 70, Full Name: Valentina Fa, Last Name: Fa, First Name: Valentina, Email: ValentinaFa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 71, Full Name: Francesco Pa, Last Name: Pa, First Name: Francesco, Email: FrancescoPa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 72, Full Name: Jana Bo, Last Name: Bo, First Name: Jana, Email: JanaBo@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 73, Full Name: Laura Ma, Last Name: Ma, First Name: Laura, Email: LauraMa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 74, Full Name: Giovanni Po, Last Name: Po, First Name: Giovanni, Email: GiovanniPo@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 75, Full Name: Paola D', Last Name: D', First Name: Paola, Email: PaolaD'@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 76, Full Name: Dario Mo, Last Name: Mo, First Name: Dario, Email: DarioMo@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 77, Full Name: Stefano Co, Last Name: Co, First Name: Stefano, Email: StefanoCo@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 78, Full Name: Francesco Za, Last Name: Za, First Name: Francesco, Email: FrancescoZa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 79, Full Name: Fabio Sa, Last Name: Sa, First Name: Fabio, Email: FabioSa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 80, Full Name: Francesco Pu, Last Name: Pu, First Name: Francesco, Email: FrancescoPu@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 81, Full Name: Alessandro Gu, Last Name: Gu, First Name: Alessandro, Email: AlessandroGu@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 82, Full Name: Matteo Ca, Last Name: Ca, First Name: Matteo, Email: MatteoCa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 83, Full Name: Gianfranco Ca, Last Name: Ca, First Name: Gianfranco, Email: GianfrancoCa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 84, Full Name: Chiara Ca, Last Name: Ca, First Name: Chiara, Email: ChiaraCa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 85, Full Name: Daniele La, Last Name: La, First Name: Daniele, Email: DanieleLa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 86, Full Name: Desiree Be, Last Name: Be, First Name: Desiree, Email: DesireeBe@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 87, Full Name: Edoardo Pa, Last Name: Pa, First Name: Edoardo, Email: EdoardoPa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 88, Full Name: Roberto Fe, Last Name: Fe, First Name: Roberto, Email: RobertoFe@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 89, Full Name: Lorenzo Ma, Last Name: Ma, First Name: Lorenzo, Email: LorenzoMa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 90, Full Name: Marco Pe, Last Name: Pe, First Name: Marco, Email: MarcoPe@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 91, Full Name: Gianni Co, Last Name: Co, First Name: Gianni, Email: GianniCo@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------
# ID: 92, Full Name: Sandro Ca, Last Name: Ca, First Name: Sandro, Email: SandroCa@demo.it, Cell: None, Active: True, Valid From: None
# ----------------------------------------

# %% [markdown]
# */utenti/{id}*
#
# * Parametri:
#   * **id**: Id del cliente di cui recuperare i dati (**richiesto**)
#
# ```json
# {
#   "id": 0,
#   "fullname": "string",
#   "cognome": "string",
#   "nome": "string",
#   "email": "string",
#   "cellulare": "string",
#   "attivo": true,
#   "dtfval": "2025-07-07T13:57:58.025Z"
# }
# ```

# %%
# Parameters -> id of the customer to retrieve its information
customer_id = 38


response = requests.get(
    f"{host}/utenti/{customer_id}",
    headers=headers
)

if response.status_code == 200:
    print(f"User with ID {customer_id} retrieved successfully.")
    user = response.json()
    print(user)
else:
    print(f"Failed to retrieve user with ID {customer_id}. Status code: {response.status_code}")
    print(response.text)
# Out:
# User with ID 38 retrieved successfully.
# {'id': 38, 'fullname': 'Ivan Pa', 'cognome': 'Pa', 'nome': 'Ivan', 'email': 'IvanPa@demo.it', 'cellulare': None, 'attivo': True, 'dtfval': None}

# %% [markdown]
# ### Calendari Utenti

# %% [markdown]
# */utenti/calendari* ritorna la lista dei calendari
#
# * Nessun parametro
#
# ```json
# [
#   {
#     "id": 0,
#     "calendario": "string"
#   }
# ]
# ```

# %%
response = requests.get(
    f"{host}/utenti/calendari",
    headers=headers
)

if response.status_code == 200:
    print("Calendars retrieved successfully.")
    calendars = response.json()
    for calendar in calendars:
        id = calendar.get("id")
        calendar = calendar.get("calendario")
        print(f"ID Calendario: {id}, Calendar: {calendar}")
        print("-" * 40)
# Out:
# Calendars retrieved successfully.
# ID Calendario: 11, Calendar: No17910
# ----------------------------------------
# ID Calendario: 39, Calendar: Iv28703
# ----------------------------------------
# ID Calendario: 40, Calendar: Sa67359
# ----------------------------------------
# ID Calendario: 41, Calendar: El21198
# ----------------------------------------
# ID Calendario: 42, Calendar: Lu26074
# ----------------------------------------
# ID Calendario: 43, Calendar: Fr58045
# ----------------------------------------
# ID Calendario: 44, Calendar: St13691
# ----------------------------------------
# ID Calendario: 45, Calendar: Li38623
# ----------------------------------------
# ID Calendario: 46, Calendar: Ca78562
# ----------------------------------------
# ID Calendario: 47, Calendar: Gu82161
# ----------------------------------------
# ID Calendario: 48, Calendar: Gu91831
# ----------------------------------------
# ID Calendario: 49, Calendar: Da81134
# ----------------------------------------
# ID Calendario: 50, Calendar: Ca4519
# ----------------------------------------
# ID Calendario: 51, Calendar: Sa52666
# ----------------------------------------
# ID Calendario: 52, Calendar: Me66547
# ----------------------------------------
# ID Calendario: 53, Calendar: Mo16959
# ----------------------------------------
# ID Calendario: 54, Calendar: Su29013
# ----------------------------------------
# ID Calendario: 55, Calendar: Ro86544
# ----------------------------------------
# ID Calendario: 56, Calendar: Ad85758
# ----------------------------------------
# ID Calendario: 57, Calendar: An43497
# ----------------------------------------
# ID Calendario: 58, Calendar: To60267
# ----------------------------------------
# ID Calendario: 59, Calendar: Ut2092
# ----------------------------------------
# ID Calendario: 60, Calendar: Ma41910
# ----------------------------------------
# ID Calendario: 61, Calendar: Lu89678
# ----------------------------------------
# ID Calendario: 62, Calendar: Si48112
# ----------------------------------------
# ID Calendario: 63, Calendar: Ba58873
# ----------------------------------------
# ID Calendario: 64, Calendar: No98126
# ----------------------------------------
# ID Calendario: 65, Calendar: No47756
# ----------------------------------------
# ID Calendario: 66, Calendar: [G31800
# ----------------------------------------
# ID Calendario: 67, Calendar: [G90517
# ----------------------------------------
# ID Calendario: 68, Calendar: Ca19852
# ----------------------------------------
# ID Calendario: 69, Calendar: Al65037
# ----------------------------------------
# ID Calendario: 70, Calendar: An52782
# ----------------------------------------
# ID Calendario: 71, Calendar: Sa65871
# ----------------------------------------
# ID Calendario: 72, Calendar: An2415
# ----------------------------------------
# ID Calendario: 73, Calendar: Co7559
# ----------------------------------------
# ID Calendario: 74, Calendar: Ma19522
# ----------------------------------------
# ID Calendario: 75, Calendar: Pa53029
# ----------------------------------------
# ID Calendario: 76, Calendar: Fa96571
# ----------------------------------------
# ID Calendario: 77, Calendar: Fr99472
# ----------------------------------------
# ID Calendario: 78, Calendar: Ja73430
# ----------------------------------------
# ID Calendario: 79, Calendar: La90347
# ----------------------------------------
# ID Calendario: 80, Calendar: Gi58084
# ----------------------------------------
# ID Calendario: 81, Calendar: Pa3717
# ----------------------------------------
# ID Calendario: 82, Calendar: Da55954
# ----------------------------------------
# ID Calendario: 83, Calendar: St3867
# ----------------------------------------
# ID Calendario: 84, Calendar: Fr87924
# ----------------------------------------
# ID Calendario: 85, Calendar: Fa36789
# ----------------------------------------
# ID Calendario: 86, Calendar: Lo54004
# ----------------------------------------
# ID Calendario: 87, Calendar: Al26978
# ----------------------------------------
# ID Calendario: 88, Calendar: Ma9831
# ----------------------------------------
# ID Calendario: 89, Calendar: Gi12921
# ----------------------------------------
# ID Calendario: 90, Calendar: Ch60071
# ----------------------------------------
# ID Calendario: 91, Calendar: Da16103
# ----------------------------------------
# ID Calendario: 92, Calendar: De36970
# ----------------------------------------
# ID Calendario: 93, Calendar: Ed50088
# ----------------------------------------
# ID Calendario: 94, Calendar: Ro57365
# ----------------------------------------
# ID Calendario: 95, Calendar: Lo841
# ----------------------------------------
# ID Calendario: 96, Calendar: Ma19704
# ----------------------------------------
# ID Calendario: 97, Calendar: Gi6593
# ----------------------------------------
# ID Calendario: 98, Calendar: Sa16382
# ----------------------------------------

# %% [markdown]
# */utenti/calendariUtente*: Ritorna una lista di calendari filtrata. Default = calendario principale dell'utente; ReadOnly = puo solo visualizzare il calendario
#
# * Parametri:
#   * *idUtente*: Id utente
#   * *idCalendario*: Id calendario
#   * *onlyDefault*: ritorna solo i calendari default se true
#
#
# ```json
# [
#   {
#     "idCalendario": 0,
#     "idUtente": 0,
#     "default": true,
#     "readOnly": true
#   }
# ]
# ```

# %%
""" params = {
    "idUtente": ... # Int32
    "idCalendario": ... # Int32
    "onlyDefault": ... # Bool
} """

params = {
    "idUtente": 38
}

response = requests.get(
    f"{host}/utenti/calendariUtente",
    headers=headers,
    params=params
)

if response.status_code == 200:
    print("User calendars retrieved successfully.")
    user_calendars = response.json()
    for user_calendar in user_calendars:
        id_calendar = user_calendar.get("idCalendario")
        id_user = user_calendar.get("idUtente")
        default = user_calendar.get("default") # True -> main user calendar, False -> secondary calendar
        read_only = user_calendar.get("readOnly") # True -> read-only calendar, False -> editable calendar
        print(f"ID Calendario: {id_calendar}, ID Utente: {id_user}, Default: {default}, Read Only: {read_only}")
        print("-" * 40)
# Out:
# User calendars retrieved successfully.
# ID Calendario: 39, ID Utente: 38, Default: True, Read Only: False
# ----------------------------------------
